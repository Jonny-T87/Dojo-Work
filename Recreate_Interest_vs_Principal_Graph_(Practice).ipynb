# %% [markdown]
# <a href="https://colab.research.google.com/github/Jonny-T87/Dojo-Work/blob/main/Recreate_Interest_vs_Principal_Graph_(Practice).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Recreate Interest vs Principal Graph (Practice)
# - Jonny Tesfahun
# - 06/06/2022

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
filename = '/content/drive/MyDrive/DojoBootCamp/Project Files/mortgages.csv'
df = pd.read_csv(filename)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             1080 non-null   int64
#  1   Starting Balance  1080 non-null   float64
#  2   Repayment         1080 non-null   float64
#  3   Interest Paid     1080 non-null   float64
#  4   Principal Paid    1080 non-null   float64
#  5   New Balance       1080 non-null   float64
#  6   Mortgage Name     1080 non-null   object
#  7   Interest Rate     1080 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 67.6+ KB

# %%
df.head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1         400000.00    1686.42        1000.00          686.42
# 1      2         399313.58    1686.42         998.28          688.14
# 2      3         398625.44    1686.42         996.56          689.86
# 3      4         397935.58    1686.42         994.83          691.59
# 4      5         397243.99    1686.42         993.10          693.32
#
#    New Balance Mortgage Name  Interest Rate
# 0    399313.58       30 Year           0.03
# 1    398625.44       30 Year           0.03
# 2    397935.58       30 Year           0.03
# 3    397243.99       30 Year           0.03
# 4    396550.67       30 Year           0.03

# %% [markdown]
# 1.  Create a filter so the Mortgage Name is '30 Year'.  Use the len() to find how many rows correspond to 30 years.

# %%
print(len(df['Mortgage Name']))
# Out:
# 1080

# %%
# 720 rows are '30 Year' loans
(df['Mortgage Name'] == '30 Year').sum()
# Out:
# 720

# %%
#filter to find '30 Year' loans
Thirty_Year = df[df['Mortgage Name'] == '30 Year']
Thirty_Year.head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1         400000.00    1686.42        1000.00          686.42
# 1      2         399313.58    1686.42         998.28          688.14
# 2      3         398625.44    1686.42         996.56          689.86
# 3      4         397935.58    1686.42         994.83          691.59
# 4      5         397243.99    1686.42         993.10          693.32
#
#    New Balance Mortgage Name  Interest Rate
# 0    399313.58       30 Year           0.03
# 1    398625.44       30 Year           0.03
# 2    397935.58       30 Year           0.03
# 3    397243.99       30 Year           0.03
# 4    396550.67       30 Year           0.03

# %% [markdown]
# 2. Create a filter for an interest rate of 3% (notice how it is written in the data!).

# %%
# 540 are 3% loans
(df['Interest Rate'] == 0.03).sum()
# Out:
# 540

# %%
# Filter for 3% loans
Interest_rate_three = df[df['Interest Rate'] == 0.03]
Interest_rate_three.head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1         400000.00    1686.42        1000.00          686.42
# 1      2         399313.58    1686.42         998.28          688.14
# 2      3         398625.44    1686.42         996.56          689.86
# 3      4         397935.58    1686.42         994.83          691.59
# 4      5         397243.99    1686.42         993.10          693.32
#
#    New Balance Mortgage Name  Interest Rate
# 0    399313.58       30 Year           0.03
# 1    398625.44       30 Year           0.03
# 2    397935.58       30 Year           0.03
# 3    397243.99       30 Year           0.03
# 4    396550.67       30 Year           0.03

# %% [markdown]
# 3. Define a new dataframe based on both the year and the interest filters you have created.

# %%
df_three = df.loc[(df['Mortgage Name'] == '30 Year') & (df['Interest Rate'] == 0.03), :]

# %%
df_three.head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1         400000.00    1686.42        1000.00          686.42
# 1      2         399313.58    1686.42         998.28          688.14
# 2      3         398625.44    1686.42         996.56          689.86
# 3      4         397935.58    1686.42         994.83          691.59
# 4      5         397243.99    1686.42         993.10          693.32
#
#    New Balance Mortgage Name  Interest Rate
# 0    399313.58       30 Year           0.03
# 1    398625.44       30 Year           0.03
# 2    397935.58       30 Year           0.03
# 3    397243.99       30 Year           0.03
# 4    396550.67       30 Year           0.03

# %% [markdown]
# 4. We have a choice for the 5% interest rate:
#
# We can just create another filter where df.['Interest Rate'] == .05
#
# - OR
#
# We can use the negate symbol (~) with our current filter to give us everything EXCEPT what we have defined in the filter. This works here because we only have two interest rates (any value that is NOT 3% is 5%)

# %%
# Using the filter for 5% rate
df[df['Interest Rate'] == 0.05]
# Out:
#       Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 360       1         400000.00    2147.29        1666.66          480.63
# 361       2         399519.37    2147.29        1664.66          482.63
# 362       3         399036.74    2147.29        1662.65          484.64
# 363       4         398552.10    2147.29        1660.63          486.66
# 364       5         398065.44    2147.29        1658.60          488.69
# ...     ...               ...        ...            ...             ...
# 1075    176          15619.91    3163.17          65.08         3098.09
# 1076    177          12521.82    3163.17          52.17         3111.00
# 1077    178           9410.82    3163.17          39.21         3123.96
# 1078    179           6286.86    3163.17          26.19         3136.98
# 1079    180           3149.88    3163.17          13.12         3150.05
#
#       New Balance Mortgage Name  Interest Rate
# 360     399519.37       30 Year           0.05
# ...

# %%
# Also using and testing the negate symbol to filter for 5% rate
Interest_rate_five = df[~(df['Interest Rate'] == 0.03)]
Interest_rate_five.head()
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 360      1         400000.00    2147.29        1666.66          480.63
# 361      2         399519.37    2147.29        1664.66          482.63
# 362      3         399036.74    2147.29        1662.65          484.64
# 363      4         398552.10    2147.29        1660.63          486.66
# 364      5         398065.44    2147.29        1658.60          488.69
#
#      New Balance Mortgage Name  Interest Rate
# 360    399519.37       30 Year           0.05
# 361    399036.74       30 Year           0.05
# 362    398552.10       30 Year           0.05
# 363    398065.44       30 Year           0.05
# 364    397576.75       30 Year           0.05

# %% [markdown]
# 5. Since we want to graph the cumulative sum of the interest paid, you can use the function .cumsum().  What are the first three values in the output for the cumulative sum of the 3% rate?
#         The first three values in output for the cumulative sum of the 3% rate for interest paid are $1000.00, $1998.28, and $2994.84.

# %%
from numpy.ma.core import cumsum
(Interest_rate_three['Interest Paid']).cumsum()
# Out:
# 0        1000.00
# 1        1998.28
# 2        2994.84
# 3        3989.67
# 4        4982.77
#          ...
# 895    304254.76
# 896    304282.20
# 897    304302.80
# 898    304316.55
# 899    304323.43
# Name: Interest Paid, Length: 540, dtype: float64

# %%
Interest_rate_three.cumsum()
# Out:
#      Month  Starting Balance   Repayment  Interest Paid  Principal Paid  \
# 0        1      4.000000e+05     1686.42        1000.00          686.42
# 1        3      7.993136e+05     3372.84        1998.28         1374.56
# 2        6      1.197939e+06     5059.26        2994.84         2064.42
# 3       10      1.595875e+06     6745.68        3989.67         2756.01
# 4       15      1.993119e+06     8432.10        4982.77         3449.33
# ..     ...               ...         ...            ...             ...
# 895  80556      1.217030e+08  1093281.28      304254.76       789026.52
# 896  80733      1.217140e+08  1096043.61      304282.20       791761.41
# 897  80911      1.217222e+08  1098805.94      304302.80       794503.14
# 898  81090      1.217277e+08  1101568.27      304316.55       797251.72
# 899  81270      1.217305e+08  1104330.60      304323.43       800007.17
#
#       New Balance                                      Mortgage Name  \
# ...

# %% [markdown]
# 6. Use plt.plot(x, y, c=color) to plot the black line (5%).  We want the x values to be the ['Month'] and the y values to be the cumulative sum of the Interest Paid.  You can use the code from the previous question to define your y values within the plt.plot() function!  Hint: for black, c = 'k'

# %%
# I dont know why plot graph looks like this, may be to much data and not enough graph space
plt.plot(Interest_rate_five['Month'], Interest_rate_five['Interest Paid'].cumsum(), c='k')

# %%
# Black graph is for 5% interest rate & interest paid
# Blue graph is for 3% interest rate & interest paid
plt.plot(Interest_rate_five['Month'], Interest_rate_five['Interest Paid'].cumsum(), c='k')
plt.plot(Interest_rate_three['Month'], Interest_rate_three['Interest Paid'].cumsum(), c='b');
