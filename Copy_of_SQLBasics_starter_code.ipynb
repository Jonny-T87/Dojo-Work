# %% [markdown]
# <a href="https://colab.research.google.com/github/Jonny-T87/Dojo-Work/blob/main/Copy_of_SQLBasics_starter_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
# <img src="https://course_report_production.s3.amazonaws.com/rich/rich_files/rich_files/2470/s300/cd-logo-blue-600x600.png" alt="Coding Dojo Logo" class="center" height="50">
#
# # SQL Basics Exercise
#
# *Make a copy of this notebook to edit!*
# ```
# File > Save a copy in Drive
# ```
#
# </center>
#
# [SQLAlchemy](https://www.sqlalchemy.org/) is a wrapper for Python that allows us to write SQL queries in Python. We will use this to practice our SQL basics in Python.
#
# First, we need to connect to a database. We will just read a table into SQL for this step. We will be creating a [SQLite](https://sqlite.org/index.html) database and loading our [data](https://drive.google.com/file/d/18MgOmIHHafoubgp2d_7GM6GWroxb0vPe/view?usp=sharing) into that database.
#
# The data (from [this source](https://data.world/sikkim/school)) describes details of various schools.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# mount data
from google.colab import drive
drive.mount('/content/drive')

# %%
# imports
import pandas as pd
from sqlalchemy import create_engine

# %%
# load data - change the path to match your drive!
df_school = pd.read_csv('/content/drive/MyDrive/DojoBootCamp/Project Files/School_Details.csv')
# make sure it loaded correctly
df_school.head(2)
# Out:
#   DistrictName EstablishmentCode  \
# 0         East             S0169
# 1         East             S0099
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
#
#                                              CRCName SchoolLevel  \
# 0  Central Pendam Government Senior Secondary School          PS
# 1  Central Pendam Government Senior Secondary School         SSS
#
#   ManagementName LocalityHabitation SubdivisionName ConstituencyName  ...  \
# 0    State Govt.             BUDANG         Gangtok          Rhenock  ...
# 1    State Govt.     CENTRAL PENDAM         Gangtok      West Pandam  ...
#
#   EstablishedDate DistrictHQDistance (in Km) CRCDistance (in Km)  \
# 0           28126                       58.0                 8.0
# 1           15342                       50.0                 0.0
#
#   BACDistance (in Km) IsRecognized RecognizedBy ContactPersonName LowestClass  \
# 0                16.0   Recognized         HRDD               NaN     Class 1
# 1                 6.0   Recognized         HRDD               NaN     Class 1
#
#   HighestClass BoardName
# 0      Class 5       NaN
# 1     Class 12  C.B.S.E.
#
# [2 rows x 30 columns]

# %%
# create sqlite engine
engine = create_engine('sqlite:///schools.db', echo=True)
# create connection to engine
conn = engine.connect()

# %%
# add the dataframe as a table in sqlite
sqlite_table = "school_details"
df_school.to_sql(sqlite_table, conn, if_exists='fail')
# Out:
# 2022-08-11 03:21:44,981 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("school_details")
# INFO:sqlalchemy.engine.Engine:PRAGMA main.table_info("school_details")
# 2022-08-11 03:21:44,986 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
# 2022-08-11 03:21:44,991 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("school_details")
# INFO:sqlalchemy.engine.Engine:PRAGMA temp.table_info("school_details")
# 2022-08-11 03:21:44,995 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
# 2022-08-11 03:21:45,008 INFO sqlalchemy.engine.Engine
# CREATE TABLE school_details (
# 	"index" BIGINT,
# 	"DistrictName" TEXT,
# 	"EstablishmentCode" TEXT,
# 	"EstablishmentName" TEXT,
# 	"BRCName" TEXT,
# 	"CRCName" TEXT,
# 	"SchoolLevel" TEXT,
# 	"ManagementName" TEXT,
# 	"LocalityHabitation" TEXT,
# 	"SubdivisionName" TEXT,
# 	"ConstituencyName" TEXT,
# 	"RevenueBlockName" TEXT,
# 	"CivicBodyName" TEXT,
# 	"WardName" TEXT,
# 	"PostOfficeName" TEXT,
# 	"PhoneNo" TEXT,
# 	"FaxNo" TEXT,
# 	"EmailID" TEXT,
# 	"Website" TEXT,
# 	"LocatedInRuralOrUrban" TEXT,
# 	"DiseCode" TEXT,
# 	"EstablishedDate" TEXT,
# 	"DistrictHQDistance (in Km)" FLOAT,
# 	"CRCDistance (in Km)" FLOAT,
# 	"BACDistance (in Km)" FLOAT,
# 	"IsRecognized" TEXT,
# 	"RecognizedBy" TEXT,
# 	"ContactPersonName" FLOAT,
# 	"LowestClass" TEXT,
# 	"HighestClass" TEXT,
# 	"BoardName" TEXT
# )
# INFO:sqlalchemy.engine.Engine:
# CREATE TABLE school_details (
# 	"index" BIGINT,
# 	"DistrictName" TEXT,
# 	"EstablishmentCode" TEXT,
# 	"EstablishmentName" TEXT,
# 	"BRCName" TEXT,
# 	"CRCName" TEXT,
# 	"SchoolLevel" TEXT,
# 	"ManagementName" TEXT,
# 	"LocalityHabitation" TEXT,
# 	"SubdivisionName" TEXT,
# 	"ConstituencyName" TEXT,
# 	"RevenueBlockName" TEXT,
# 	"CivicBodyName" TEXT,
# 	"WardName" TEXT,
# 	"PostOfficeName" TEXT,
# 	"PhoneNo" TEXT,
# 	"FaxNo" TEXT,
# 	"EmailID" TEXT,
# 	"Website" TEXT,
# 	"LocatedInRuralOrUrban" TEXT,
# 	"DiseCode" TEXT,
# 	"EstablishedDate" TEXT,
# 	"DistrictHQDistance (in Km)" FLOAT,
# 	"CRCDistance (in Km)" FLOAT,
# 	"BACDistance (in Km)" FLOAT,
# 	"IsRecognized" TEXT,
# 	"RecognizedBy" TEXT,
# 	"ContactPersonName" FLOAT,
# 	"LowestClass" TEXT,
# 	"HighestClass" TEXT,
# 	"BoardName" TEXT
# )
# 2022-08-11 03:21:45,020 INFO sqlalchemy.engine.Engine [no key 0.01141s] ()
# INFO:sqlalchemy.engine.Engine:[no key 0.01141s] ()
# 2022-08-11 03:21:45,037 INFO sqlalchemy.engine.Engine COMMIT
# INFO:sqlalchemy.engine.Engine:COMMIT
# 2022-08-11 03:21:45,040 INFO sqlalchemy.engine.Engine CREATE INDEX ix_school_details_index ON school_details ("index")
# INFO:sqlalchemy.engine.Engine:CREATE INDEX ix_school_details_index ON school_details ("index")
# 2022-08-11 03:21:45,044 INFO sqlalchemy.engine.Engine [no key 0.00345s] ()
# INFO:sqlalchemy.engine.Engine:[no key 0.00345s] ()
# 2022-08-11 03:21:45,058 INFO sqlalchemy.engine.Engine COMMIT
# INFO:sqlalchemy.engine.Engine:COMMIT
# 2022-08-11 03:21:45,081 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2022-08-11 03:21:45,150 INFO sqlalchemy.engine.Engine INSERT INTO school_details ("index", "DistrictName", "EstablishmentCode", "EstablishmentName", "BRCName", "CRCName", "SchoolLevel", "ManagementName", "LocalityHabitation", "SubdivisionName", "ConstituencyName", "RevenueBlockName", "CivicBodyName", "WardName", "PostOfficeName", "PhoneNo", "FaxNo", "EmailID", "Website", "LocatedInRuralOrUrban", "DiseCode", "EstablishedDate", "DistrictHQDistance (in Km)", "CRCDistance (in Km)", "BACDistance (in Km)", "IsRecognized", "RecognizedBy", "ContactPersonName", "LowestClass", "HighestClass", "BoardName") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# INFO:sqlalchemy.engine.Engine:INSERT INTO school_details ("index", "DistrictName", "EstablishmentCode", "EstablishmentName", "BRCName", "CRCName", "SchoolLevel", "ManagementName", "LocalityHabitation", "SubdivisionName", "ConstituencyName", "RevenueBlockName", "CivicBodyName", "WardName", "PostOfficeName", "PhoneNo", "FaxNo", "EmailID", "Website", "LocatedInRuralOrUrban", "DiseCode", "EstablishedDate", "DistrictHQDistance (in Km)", "CRCDistance (in Km)", "BACDistance (in Km)", "IsRecognized", "RecognizedBy", "ContactPersonName", "LowestClass", "HighestClass", "BoardName") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2022-08-11 03:21:45,157 INFO sqlalchemy.engine.Engine [generated in 0.05870s] ((0, 'East', 'S0169', 'BUDANG GOVERNMENT PRIMARY SCHOOL (E)', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'State Govt.', 'BUDANG', 'Gangtok', 'Rhenock', 'Central Pendam', 'Central Pendam', 'Sajong', 'Upper Pendam', None, None, None, None, 'Urban Area', None, '28126', 58.0, 8.0, 16.0, 'Recognized', 'HRDD', None, 'Class 1', 'Class 5', None), (1, 'East', 'S0099', 'CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'SSS', 'State Govt.', 'CENTRAL PENDAM', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Karmithang', 'Upper Pendam', '3592263812', None, None, None, 'Urban Area', '800401', '15342', 50.0, 0.0, 6.0, 'Recognized', 'HRDD', None, 'Class 1', 'Class 12', 'C.B.S.E.'), (2, 'East', 'S0848', 'CENTRAL POINT ACADEMY, CENTRAL PENDAM', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'SS', 'Private (Unaided)', 'UPPER BHURUNG CENTRAL PENDAM', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Burung', 'Upper Pendam', '03592263809/263960', None, 'ksu_5162@yahoo.com', 'www.facebook.com/khanalkeshav (Group-CPA)', 'Urban Area', None, '37257.38680555556', 49.0, 1.5, 6.0, 'Recognized', 'HRDD, GOVT. OF SIKKIM', None, 'Class 1', 'Class 10', 'C.B.S.E.'), (3, 'East', 'S0190', 'CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'JHS', 'State Govt.', 'CHEURIBOTEY', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Cheuribotey', 'Duga', None, None, None, None, 'Urban Area', None, '28856', 60.0, 6.0, 6.0, 'Recognized', 'State Govt.', None, 'Class 1', 'Class 8', None), (4, 'East', 'S0111', 'DUGA GOVERNMENT SECONDARY SCHOOL', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'SS', 'State Govt.', 'DUGA', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Duga', 'Duga', '9832082915', None, 'dugaschool@gmail.com', None, 'Urban Area', None, '1828', 52.0, 0.0, 0.5, 'Recognized', 'c.b.s.e.', None, 'Class 1', 'Class 10', 'C.B.S.E.'), (5, 'East', 'S0856', 'EASWARAMMA SAI GURUKOOL ACCADEMY', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'Private (Unaided)', 'RALUNG', 'Gangtok', 'West Pandam', 'Central Pendam', 'West Pendam', 'Ralang', 'West Pendam', '9733056624', None, None, None, 'Urban Area', None, '40179.66805555556', 0.0, 0.2, 0.2, 'Recognized', None, None, 'Class 1', 'Class 5', None), (6, 'East', 'S0870', 'ETERNAL ENGLISH SCHOOL, WEST PENDAM', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'Private (Unaided)', 'SAKHU WEST PENDAM', 'Gangtok', 'West Pandam', 'West Pendam', 'West Pendam', 'Sakhu', 'Sakhu Busty', '9734190544', None, None, None, 'Urban Area', None, '37300.66805555556', 42.0, 3.0, 4.0, 'Recognized', 'HRDD OF SIKKIM', None, 'Class 1', 'Class 5', None), (7, 'East', 'S0157', 'KHANI GOAN GOVERNMENT PRIMARY SCHOOL', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'State Govt.', 'WEST PENDAM', 'Gangtok', 'West Pandam', 'West Pendam', 'West Pendam', 'Khanigaon', 'West Pendam', '9832470263', None, None, None, 'Urban Area', '801801', '29587', 45.0, 5.0, 4.0, 'Recognized', 'State Govt.', None, 'Class 1', 'Class 5', 'C.B.S.E.')  ... displaying 10 of 1249 total bound parameter sets ...  (1247, 'West', 'S0340', 'TINGTING GAON GOVERNMENT PRIMARY SCHOOL', 'Yuksom Brc', 'Yuksom Government Secondary School', 'PS', 'State Govt.', 'TING TING GAON', 'Gyalshing', 'Yoksam-Tashiding', 'Yoksam', 'Yuksom', 'Tingting', 'Yuksom', '9593377402', None, None, None, 'Urban Area', '100282', '29587', 36.0, 3.0, 6.0, 'Recognized', 'STATE GOVERNMENT', None, 'Class 1', 'Class 5', None), (1248, 'West', 'S0542', 'TSONG GOVERNMENT PRIMARY SCHOOL', 'Yuksom Brc', 'Yuksom Government Secondary School', 'PS', 'State Govt.', 'TSONG', 'Gyalshing', 'Yoksam-Tashiding', 'Yoksam', 'Yuksom', 'Yoksam', 'Yuksom', No ...
# INFO:sqlalchemy.engine.Engine:[generated in 0.05870s] ((0, 'East', 'S0169', 'BUDANG GOVERNMENT PRIMARY SCHOOL (E)', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'State Govt.', 'BUDANG', 'Gangtok', 'Rhenock', 'Central Pendam', 'Central Pendam', 'Sajong', 'Upper Pendam', None, None, None, None, 'Urban Area', None, '28126', 58.0, 8.0, 16.0, 'Recognized', 'HRDD', None, 'Class 1', 'Class 5', None), (1, 'East', 'S0099', 'CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'SSS', 'State Govt.', 'CENTRAL PENDAM', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Karmithang', 'Upper Pendam', '3592263812', None, None, None, 'Urban Area', '800401', '15342', 50.0, 0.0, 6.0, 'Recognized', 'HRDD', None, 'Class 1', 'Class 12', 'C.B.S.E.'), (2, 'East', 'S0848', 'CENTRAL POINT ACADEMY, CENTRAL PENDAM', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'SS', 'Private (Unaided)', 'UPPER BHURUNG CENTRAL PENDAM', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Burung', 'Upper Pendam', '03592263809/263960', None, 'ksu_5162@yahoo.com', 'www.facebook.com/khanalkeshav (Group-CPA)', 'Urban Area', None, '37257.38680555556', 49.0, 1.5, 6.0, 'Recognized', 'HRDD, GOVT. OF SIKKIM', None, 'Class 1', 'Class 10', 'C.B.S.E.'), (3, 'East', 'S0190', 'CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'JHS', 'State Govt.', 'CHEURIBOTEY', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Cheuribotey', 'Duga', None, None, None, None, 'Urban Area', None, '28856', 60.0, 6.0, 6.0, 'Recognized', 'State Govt.', None, 'Class 1', 'Class 8', None), (4, 'East', 'S0111', 'DUGA GOVERNMENT SECONDARY SCHOOL', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'SS', 'State Govt.', 'DUGA', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Duga', 'Duga', '9832082915', None, 'dugaschool@gmail.com', None, 'Urban Area', None, '1828', 52.0, 0.0, 0.5, 'Recognized', 'c.b.s.e.', None, 'Class 1', 'Class 10', 'C.B.S.E.'), (5, 'East', 'S0856', 'EASWARAMMA SAI GURUKOOL ACCADEMY', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'Private (Unaided)', 'RALUNG', 'Gangtok', 'West Pandam', 'Central Pendam', 'West Pendam', 'Ralang', 'West Pendam', '9733056624', None, None, None, 'Urban Area', None, '40179.66805555556', 0.0, 0.2, 0.2, 'Recognized', None, None, 'Class 1', 'Class 5', None), (6, 'East', 'S0870', 'ETERNAL ENGLISH SCHOOL, WEST PENDAM', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'Private (Unaided)', 'SAKHU WEST PENDAM', 'Gangtok', 'West Pandam', 'West Pendam', 'West Pendam', 'Sakhu', 'Sakhu Busty', '9734190544', None, None, None, 'Urban Area', None, '37300.66805555556', 42.0, 3.0, 4.0, 'Recognized', 'HRDD OF SIKKIM', None, 'Class 1', 'Class 5', None), (7, 'East', 'S0157', 'KHANI GOAN GOVERNMENT PRIMARY SCHOOL', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'State Govt.', 'WEST PENDAM', 'Gangtok', 'West Pandam', 'West Pendam', 'West Pendam', 'Khanigaon', 'West Pendam', '9832470263', None, None, None, 'Urban Area', '801801', '29587', 45.0, 5.0, 4.0, 'Recognized', 'State Govt.', None, 'Class 1', 'Class 5', 'C.B.S.E.')  ... displaying 10 of 1249 total bound parameter sets ...  (1247, 'West', 'S0340', 'TINGTING GAON GOVERNMENT PRIMARY SCHOOL', 'Yuksom Brc', 'Yuksom Government Secondary School', 'PS', 'State Govt.', 'TING TING GAON', 'Gyalshing', 'Yoksam-Tashiding', 'Yoksam', 'Yuksom', 'Tingting', 'Yuksom', '9593377402', None, None, None, 'Urban Area', '100282', '29587', 36.0, 3.0, 6.0, 'Recognized', 'STATE GOVERNMENT', None, 'Class 1', 'Class 5', None), (1248, 'West', 'S0542', 'TSONG GOVERNMENT PRIMARY SCHOOL', 'Yuksom Brc', 'Yuksom Government Secondary School', 'PS', 'State Govt.', 'TSONG', 'Gyalshing', 'Yoksam-Tashiding', 'Yoksam', 'Yuksom', 'Yoksam', 'Yuksom', None, None, None, None, 'U ...
# 2022-08-11 03:21:45,187 INFO sqlalchemy.engine.Engine COMMIT
# INFO:sqlalchemy.engine.Engine:COMMIT

# %% [markdown]
# ## SELECT & FROM
#
# 1. Get the EstablishmentName, SchoolLevel, and Website columns.
#
# We can actually use Pandas to run SQL queries! To do this, we write a SQL query in a multi-line string. Simply replace the text in the multi-line string below with your SQL query and run the cell to query your data.

# %%
# Write your SQL query in this string
sql = """
SELECT *
FROM school_details
LIMIT 3;
"""

# Read the sql query into pandas to view the results
pd.read_sql_query(sql, engine)
# Out:
# 2022-08-11 03:23:01,259 INFO sqlalchemy.engine.Engine
# SELECT *
# FROM school_details
# LIMIT 3;
# INFO:sqlalchemy.engine.Engine:
# SELECT *
# FROM school_details
# LIMIT 3;
# 2022-08-11 03:23:01,268 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#    index DistrictName EstablishmentCode  \
# 0      0         East             S0169
# 1      1         East             S0099
# 2      2         East             S0848
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
# 2              CENTRAL POINT ACADEMY, CENTRAL PENDAM  Duga Brc
#
#                                              CRCName SchoolLevel  \
# 0  Central Pendam Government Senior Secondary School          PS
# 1  Central Pendam Government Senior Secondary School         SSS
# 2  Central Pendam Government Senior Secondary School          SS
#
#       ManagementName            LocalityHabitation SubdivisionName  ...  \
# 0        State Govt.                        BUDANG         Gangtok  ...
# 1        State Govt.                CENTRAL PENDAM         Gangtok  ...
# 2  Private (Unaided)  UPPER BHURUNG CENTRAL PENDAM         Gangtok  ...
#
#      EstablishedDate DistrictHQDistance (in Km) CRCDistance (in Km)  \
# 0              28126                       58.0                 8.0
# 1              15342                       50.0                 0.0
# 2  37257.38680555556                       49.0                 1.5
#
#   BACDistance (in Km) IsRecognized           RecognizedBy ContactPersonName  \
# 0                16.0   Recognized                   HRDD              None
# 1                 6.0   Recognized                   HRDD              None
# 2                 6.0   Recognized  HRDD, GOVT. OF SIKKIM              None
#
#   LowestClass HighestClass BoardName
# 0     Class 1      Class 5      None
# 1     Class 1     Class 12  C.B.S.E.
# 2     Class 1     Class 10  C.B.S.E.
#
# [3 rows x 31 columns]

# %% [markdown]
# ## WHERE
#
# 2. Display the EstablishmentName and DistrictHQDistance (in Km) for schools where the DistrictHQDistance (in Km) is more than 100 Km.

# %%
# Write your SQL query in this string
sql = """
SELECT EstablishmentName, `DistrictHQDistance (in Km)`
FROM school_details
WHERE `DistrictHQDistance (in Km)` > 100;
"""

# Read the sql query into pandas to view the results
pd.read_sql_query(sql, engine)
# Out:
# 2022-08-11 03:25:49,359 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, `DistrictHQDistance (in Km)`
# FROM school_details
# WHERE `DistrictHQDistance (in Km)` > 100;
# INFO:sqlalchemy.engine.Engine:
# SELECT EstablishmentName, `DistrictHQDistance (in Km)`
# FROM school_details
# WHERE `DistrictHQDistance (in Km)` > 100;
# 2022-08-11 03:25:49,369 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                                 EstablishmentName  DistrictHQDistance (in Km)
# 0              DODACHEN GOVERNMENT PRIMARY SCHOOL                       150.0
# 1               DEOLING GOVERNMENT PRIMARY SCHOOL                       107.0
# 2                   PEMA TSEL ACADEMY(PHADAMCHEN)                       110.0
# 3                ZULUCK GOVERNMENT PRIMARY SCHOOL                       120.0
# 4               BHARENG GOVERNMENT PRIMARY SCHOOL                       150.0
# 5                HIMALAYAN RISING ACADEMY, OKHREY                       103.0
# 6             PIUREYTAR GOVERNMENT PRIMARY SCHOOL                       102.0
# 7               RIBDI GOVERNMENT SECONDARY SCHOOL                       120.0
# 8  MILLING KARMATAR GOVERNMENT JUNIOR HIGH SCHOOL                       170.0
# 9       SORENG GOVERNMENT SENIOR SECONDARY SCHOOL                       115.0

# %% [markdown]
# 3. Display the EstablishmentName, SchoolLevel, DistrictHQDistance (in Km) for schools where the school level is "JHS."

# %%
# Write your SQL query in this string
sql = """
SELECT EstablishmentName, SchoolLevel, `DistrictHQDistance (in Km)`
FROM school_details
WHERE SchoolLevel = 'JHS';
"""

# Read the sql query into pandas to view the results
pd.read_sql_query(sql, engine)
# Out:
# 2022-08-11 03:38:12,960 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, SchoolLevel, `DistrictHQDistance (in Km)`
# FROM school_details
# WHERE SchoolLevel = 'JHS';
# INFO:sqlalchemy.engine.Engine:
# SELECT EstablishmentName, SchoolLevel, `DistrictHQDistance (in Km)`
# FROM school_details
# WHERE SchoolLevel = 'JHS';
# 2022-08-11 03:38:12,964 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                                  EstablishmentName SchoolLevel  \
# 0    CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)         JHS
# 1                 PADMA KUMARI PUBLIC SCHOOL, DUGA         JHS
# 2             SAJONG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 3        SINGLEYBONG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 4                            SUNRISE ACADEMY, DUGA         JHS
# ..                                             ...         ...
# 335         TIMBRONG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 336                  VIDYA SAGAR GYANPETH, TATHANG         JHS
# 337           HIMALAYAN RADIANT ACADEMY, TASHIDING         JHS
# 338          GOOD SHEPHERD NURSERY SCHOOL , YUKSAM         JHS
# 339                    LIFE VISION ACADEMY, YUKSAM         JHS
#
#      DistrictHQDistance (in Km)
# 0                          60.0
# 1                          48.0
# 2                          57.0
# 3                          38.0
# 4                          47.0
# ..                          ...
# 335                        32.0
# 336                        25.0
# 337                        35.0
# 338                        52.0
# 339                        32.0
#
# [340 rows x 3 columns]

# %% [markdown]
# ## Wildcards & LIKE
#
# 4. Display the EstablishmentName, SchoolLevel, DistrictHQDistance (in Km) for schools where the name of the school contains the words "JUNIOR HIGH."

# %%
# Write your SQL query in this string
sql = """
SELECT EstablishmentName, SchoolLevel, `DistrictHQDistance (in Km)`
FROM school_details
WHERE EstablishmentName LIKE '%JUNIOR HIGH%';
"""

# Read the sql query into pandas to view the results
pd.read_sql_query(sql, engine)
# Out:
# 2022-08-11 03:40:44,263 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, SchoolLevel, `DistrictHQDistance (in Km)`
# FROM school_details
# WHERE EstablishmentName LIKE '%JUNIOR HIGH%';
# INFO:sqlalchemy.engine.Engine:
# SELECT EstablishmentName, SchoolLevel, `DistrictHQDistance (in Km)`
# FROM school_details
# WHERE EstablishmentName LIKE '%JUNIOR HIGH%';
# 2022-08-11 03:40:44,269 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                                   EstablishmentName SchoolLevel  \
# 0     CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)         JHS
# 1              SAJONG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 2         SINGLEYBONG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 3             BORDANG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 4        RANGPO BAZAR GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# ..                                              ...         ...
# 179           TAMATAM GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 180   UPPER GERETHANG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 181        DARAPTHANG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 182  MIDDLE CHONGRANG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 183          TIMBRONG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
#
#      DistrictHQDistance (in Km)
# 0                          60.0
# 1                          57.0
# 2                          38.0
# 3                          33.0
# 4                          47.0
# ..                          ...
# 179                        55.0
# 180                        60.0
# 181                        28.0
# 182                        60.0
# 183                        32.0
#
# [184 rows x 3 columns]

# %% [markdown]
# ## LIMIT & ORDER BY
#
# 5. Display the EstablishmentName, SchoolLevel, DistrictHQDistance (in Km) for schools where the name of the school starts with the letter "C." Sort the results alphabetically by school name and limit the results of the query to 10 rows.

# %%
# Write your SQL query in this string
sql = """
SELECT EstablishmentName, SchoolLevel, `DistrictHQDistance (in Km)`
FROM school_details
WHERE EstablishmentName LIKE 'C%'
ORDER BY EstablishmentName DESC
LIMIT 10;
"""

# Read the sql query into pandas to view the results
pd.read_sql_query(sql, engine)
# Out:
# 2022-08-11 03:43:28,191 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, SchoolLevel, `DistrictHQDistance (in Km)`
# FROM school_details
# WHERE EstablishmentName LIKE 'C%'
# ORDER BY EstablishmentName DESC
# LIMIT 10;
# INFO:sqlalchemy.engine.Engine:
# SELECT EstablishmentName, SchoolLevel, `DistrictHQDistance (in Km)`
# FROM school_details
# WHERE EstablishmentName LIKE 'C%'
# ORDER BY EstablishmentName DESC
# LIMIT 10;
# 2022-08-11 03:43:28,201 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                               EstablishmentName SchoolLevel  \
# 0                COMMITTEE SCHOOL, LOWER TIKPUR          PS
# 1          CHUNBHATTI GOVERNMENT PRIMARY SCHOOL          PS
# 2         CHUMLOK GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 3          CHUMBONG GOVERNMENT SECONDARY SCHOOL          SS
# 4             CHUMANG GOVERNMENT PRIMARY SCHOOL          PS
# 5  CHUJACHEN LUNGCHOK GOVERNMENT PRIMARY SCHOOL          PS
# 6  CHUJACHEN GOVERNMENT SENIOR SECONDARY SCHOOL         SSS
# 7        CHUJA MARTAM GOVERNMENT PRIMARY SCHOOL          PS
# 8         CHUBA GOVERNMENT SECONDARY SCHOOL (S)          SS
# 9       CHUBA GOVERNMENT JUNIOR HIGH SCHOOL (E)         JHS
#
#    DistrictHQDistance (in Km)
# 0                        85.0
# 1                        62.0
# 2                        25.0
# 3                        75.0
# 4                        52.0
# 5                        80.0
# 6                        70.0
# 7                        25.0
# 8                        24.0
# 9                        21.0

# %% [markdown]
# 6. Display the names of schools in urban areas. Sort the results in reverse alphabetical order.

# %%
# Write your SQL query in this string
sql = """
SELECT EstablishmentName
FROM school_details
ORDER BY EstablishmentName DESC;
"""

# Read the sql query into pandas to view the results
pd.read_sql_query(sql, engine)
# Out:
# 2022-08-11 03:44:47,820 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName
# FROM school_details
# ORDER BY EstablishmentName DESC;
# INFO:sqlalchemy.engine.Engine:
# SELECT EstablishmentName
# FROM school_details
# ORDER BY EstablishmentName DESC;
# 2022-08-11 03:44:47,827 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                                       EstablishmentName
# 0                      ZULUCK GOVERNMENT PRIMARY SCHOOL
# 1                      ZOOM GOVERNMENT SECONDARY SCHOOL
# 2                 ZITLANG GOVERNMENT JUNIOR HIGH SCHOOL
# 3                      ZINGLA GOVERNMENT PRIMARY SCHOOL
# 4                                  ZENITH PUBLIC SCHOOL
# ...                                                 ...
# 1244                AARUBOTEY GOVERNMENT PRIMARY SCHOOL
# 1245                  AAPGAZI GOVERNMENT PRIMARY SCHOOL
# 1246             4TH MILE GOVERNMENT JUNIOR HIGH SCHOOL
# 1247                10TH MILE GOVERNMENT PRIMARY SCHOOL
# 1248  (I.E.C) INDIAN EVANGALISTIC CRUSADE MISSION PR...
#
# [1249 rows x 1 columns]

# %% [markdown]
# ## Aliasing
#
# 7. Repeat the previous query, but rename the column displayed to "name".

# %%
# Write your SQL query in this string
sql = """
SELECT EstablishmentName AS name
FROM school_details
ORDER BY name DESC;
"""

# Read the sql query into pandas to view the results
pd.read_sql_query(sql, engine)
# Out:
# 2022-08-11 03:45:35,395 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName AS name
# FROM school_details
# ORDER BY name DESC;
# INFO:sqlalchemy.engine.Engine:
# SELECT EstablishmentName AS name
# FROM school_details
# ORDER BY name DESC;
# 2022-08-11 03:45:35,401 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                                                    name
# 0                      ZULUCK GOVERNMENT PRIMARY SCHOOL
# 1                      ZOOM GOVERNMENT SECONDARY SCHOOL
# 2                 ZITLANG GOVERNMENT JUNIOR HIGH SCHOOL
# 3                      ZINGLA GOVERNMENT PRIMARY SCHOOL
# 4                                  ZENITH PUBLIC SCHOOL
# ...                                                 ...
# 1244                AARUBOTEY GOVERNMENT PRIMARY SCHOOL
# 1245                  AAPGAZI GOVERNMENT PRIMARY SCHOOL
# 1246             4TH MILE GOVERNMENT JUNIOR HIGH SCHOOL
# 1247                10TH MILE GOVERNMENT PRIMARY SCHOOL
# 1248  (I.E.C) INDIAN EVANGALISTIC CRUSADE MISSION PR...
#
# [1249 rows x 1 columns]

# %%
# Close the database connection
conn.close()
